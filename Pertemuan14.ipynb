# %%
# Slide 10

import networkx as nx
import matplotlib.pyplot as plt

# %%
# slide 11

vertices = range(1, 10)
edges = [(7,2), (2,3), (7,4), (4,5), (7,3), (7,5), (1,6), (1,7), (2,8), (2,9)]

G = nx.Graph()

G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
# Slide 12

G = nx.Graph()
G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# %%
# Slide 13 dan 14

#Gambar Nodes dan Edges beserta labelnya menggunakan NetworkX. NF berwarna hijau, sedangkan F berwarna merah
nx.draw_networkx_nodes(G, pos, nodelist=[1,4,3,8,9], label=True, node_color='g', node_size=1300)
nx.draw_networkx_nodes(G, pos, nodelist=[2,5,6,7], label=True, node_color='r', node_size=1300)
nx.draw_networkx_edges(G, pos, edges, width=3, alpha=0.5, edge_color='b')

labels = {}
labels[1]=r'1 NF'
labels[2]=r'2 F'
labels[3]=r'3 NF'
labels[4]=r'4 NF'
labels[5]=r'5 F'
labels[6]=r'6 F'
labels[7]=r'7 F'
labels[8]=r'8 NF'
labels[9]=r'9 NF'


nx.draw_networkx_labels(G, pos, labels, font_size=16)
nx.draw_networkx_labels(G, pos, labels, font_size=10)
# Out:
# {1: Text(-0.5778216679207244, -0.1542143365621884, '1 NF'),
#  2: Text(0.3121666191167391, 0.3185016014807027, '2 F'),
#  3: Text(0.27706910163548065, 0.016763964332625624, '3 NF'),
#  4: Text(-0.1265106801211069, -0.5555606098612256, '4 NF'),
#  5: Text(0.12589356444442112, -0.5477156970207613, '5 F'),
#  6: Text(-1.0, -0.1767375206396386, '6 F'),
#  7: Text(-0.03505138089052365, -0.15211843890079083, '7 F'),
#  8: Text(0.7147791249092956, 0.4993767936629117, '8 NF'),
#  9: Text(0.30947531882641843, 0.7517042435083644, '9 NF')}

# %%
vertices = range(1, 10)
edges = [(7,2), (2,3), (7,4), (4,5), (7,3), (7,5), (1,6), (1,7), (2,8), (2,9)]

G = nx.Graph()

G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos = nx.spring_layout(G)

# Menghitung derajat setiap node
degree_values = dict(G.degree())

# DOS Values
dos_values = {node: degree for node, degree in degree_values.items()}

# Menampilkan DOS Values
print("DOS VALUES")
for node, dos in dos_values.items():
  print(f"{node}: {dos}")

# Normalisasi nilai derajat ke dalam rentang 0-9
max_degree = max(degree_values.values())

# Menghitung DOS values (derajat yang dinormalisasi)
normalized_dos_values = {node: round((degree / max_degree) * 9, 2) for node, degree in degree_values.items()}

# Menampilkan DOS values (derajat yang dinormalisasi)
print("\nNormalized DOS Values:")
for node, normalized_dos in normalized_dos_values.items():
  print(f"{node}: {normalized_dos}")
# Out:
# DOS VALUES
# 1: 2
# 2: 4
# 3: 2
# 4: 2
# 5: 2
# 6: 1
# 7: 5
# 8: 1
# 9: 1
#
# Normalized DOS Values:
# 1: 3.6
# 2: 7.2
# 3: 3.6
# 4: 3.6
# 5: 3.6
# 6: 1.8
# 7: 9.0
# 8: 1.8
# 9: 1.8

# %%
# Slide 29
# Latihan 1

# Latihan 1
vertices1 = range(0, 10)
edges1 = [(1,2), (1,7), (2,3), (2,6), (3,4), (3,6), (6,5), (7,6), (7,8), (7,9), (7,10), (8,9)]

G1 = nx.Graph()

G1.add_nodes_from(vertices1)
G1.add_edges_from(edges1)
pos1 = nx.spring_layout(G1)

nx.draw_networkx_nodes(G1, pos1, nodelist=[1,7,10,4,5], label=True, node_color='r', node_size=1300)
nx.draw_networkx_nodes(G1, pos1, nodelist=[2,3,6,8,9], label=True, node_color='g', node_size=1300)
nx.draw_networkx_edges(G1, pos1, edges1, width=3, alpha=0.5, edge_color='b')

labels1 = {}
labels1[1]=r'1 F'
labels1[2]=r'2 NF'
labels1[3]=r'3 NF'
labels1[4]=r'4 F'
labels1[5]=r'5 F'
labels1[6]=r'6 NF'
labels1[7]=r'7 F'
labels1[8]=r'8 NF'
labels1[9]=r'9 NF'
labels1[10]=r'10 F'


nx.draw_networkx_labels(G1, pos1, labels1, font_size=16)
# Out:
# {1: Text(0.13762051961867947, -0.15086282524156605, '1 F'),
#  2: Text(0.25498376496324043, 0.035862186993474265, '2 NF'),
#  3: Text(0.2740086013472264, 0.2136286551839152, '3 NF'),
#  4: Text(0.3562707224829624, 0.41359655408841556, '4 F'),
#  5: Text(0.4034362249076332, -0.013669860711600387, '5 F'),
#  6: Text(0.1678252384260502, -0.00011001604498230369, '6 NF'),
#  7: Text(-0.04898638322383371, -0.2040224097305471, '7 F'),
#  8: Text(-0.19766182011304018, -0.36158341734935484, '8 NF'),
#  9: Text(-0.08851137275246053, -0.41545569050253456, '9 NF'),
#  10: Text(-0.25898549565645806, -0.14767584756897453, '10 F')}

# %%
# Slde 30
# Latihan 2
vertices2 = range(0, 10)
edges2 = [(1,2), (1,3), (2,3), (2,12), (3,4), (4,6), (4,5), (4,7), (7,8), (5,8), (6,9), (8,9), (3,11), (3,10), (11,12), (12,13)]

G2 = nx.Graph()

G2.add_nodes_from(vertices2)
G2.add_edges_from(edges2)
pos2 = nx.spring_layout(G2)

nx.draw_networkx_nodes(G2, pos2, nodelist=[1,2,3,11,10,12], label=True, node_color='r', node_size=1000)
nx.draw_networkx_nodes(G2, pos2, nodelist=[13,4,5,6,7,8,9], label=True, node_color='g', node_size=1000)
nx.draw_networkx_edges(G2, pos2, edges2, width=3, alpha=0.5, edge_color='b')

labels2 = {}
labels2[1]=r'1 F'
labels2[2]=r'2 F'
labels2[3]=r'3 F'
labels2[4]=r'4 NF'
labels2[5]=r'5 NF'
labels2[6]=r'6 NF'
labels2[7]=r'7 NF'
labels2[8]=r'8 NF'
labels2[9]=r'9 NF'
labels2[10]=r'10 F'
labels2[11]=r'11 F'
labels2[12]=r'12 F'
labels2[13]=r'13 NF'


nx.draw_networkx_labels(G2, pos2, labels2, font_size=10)
# Out:
# {1: Text(0.20147101734304299, 0.04619859729528876, '1 F'),
#  2: Text(0.18520213886200973, -0.06517692077148035, '2 F'),
#  3: Text(0.09774909192807296, 0.06639099857174066, '3 F'),
#  4: Text(-0.13519231777380755, 0.15151350093567204, '4 NF'),
#  5: Text(-0.29005720566919946, 0.09925754634504173, '5 NF'),
#  6: Text(-0.24635086472947754, 0.292738748659009, '6 NF'),
#  7: Text(-0.2700111193965108, 0.1823604753347016, '7 NF'),
#  8: Text(-0.3867272502825154, 0.19129822564122304, '8 NF'),
#  9: Text(-0.3873035884279631, 0.31642501517259575, '9 NF'),
#  10: Text(0.16260594812692386, 0.2008743438178979, '10 F'),
#  11: Text(0.25502209157672, -0.04158339576137466, '11 F'),
#  12: Text(0.30623486853004167, -0.16491445988567, '12 F'),
#  13: Text(0.4045496931800847, -0.27538267535464583, '13 NF')}
